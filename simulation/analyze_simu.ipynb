# %%
import pickle 
import pandas as pd
import sys
sys.path.append('/home/dxie/myPy/VEBGLM/src')

# %%
import sys
import os
current_dir = os.getcwd()
# Get the parent directory
parent_dir = os.path.dirname(current_dir)
# Add the parent directory to the system path
sys.path.append(parent_dir)
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pickle

import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
with open('/home/dxie/myPy/VEBGLM-paper/simulation/results/simu_res_rho.pkl', 'rb') as f:
    res = pickle.load(f)
results_df = pd.DataFrame(res)

# %%
res = results_df.groupby(['model', 'metric','n','p','r','s','beta_dist']).median().reset_index()

# %%
# res[(res['metric']=='recall_score') ]
res[(res['metric']=='accuracy_score') & (res['r']==0.95) ]
# Out:
#                           model          metric    n     p     r   s  \
# 9                       L0Learn  accuracy_score  500  1000  0.95  20
# 59                          MCP  accuracy_score  500  1000  0.95  20
# 109                        SCAD  accuracy_score  500  1000  0.95  20
# 160            VEBGLM-ash-lbfgs  accuracy_score  500  1000  0.95  20
# 215  VEBGLM-point_laplace-lbfgs  accuracy_score  500  1000  0.95  20
# 270   VEBGLM-point_normal-lbfgs  accuracy_score  500  1000  0.95  20
# 324                    bayesreg  accuracy_score  500  1000  0.95  20
# 375                  elasticnet  accuracy_score  500  1000  0.95  20
# 429                       lasso  accuracy_score  500  1000  0.95  20
# 479                       ridge  accuracy_score  500  1000  0.95  20
# 529                    sparsevb  accuracy_score  500  1000  0.95  20
# 579                      varbvs  accuracy_score  500  1000  0.95  20
#
#     beta_dist  rep     score    run_time
# ...
