# %%
import pickle 
import pandas as pd
import sys
sys.path.append('/home/mypro3/myPy/VEBGLM/src')

# %%
import sys
import os
current_dir = os.getcwd()
# Get the parent directory
parent_dir = os.path.dirname(current_dir)
# Add the parent directory to the system path
sys.path.append(parent_dir)
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pickle

import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
with open('/home/mypro3/myPy/VEBGLM-paper/simulation/results/simu_metric_rho.pkl', 'rb') as f:
    res = pickle.load(f)
results_df = pd.DataFrame(res)

# %%
res = results_df.groupby(['model', 'metric','n','p','r','s','beta_dist']).median().reset_index()

# %%
# res[(res['metric']=='recall_score') ]
res[(res['metric']=='accuracy_score') & (res['r']==0.3) & (res['p']==1000)]
# Out:
#                     model          metric    n     p    r   s beta_dist  rep  \
# 3                 L0Learn  accuracy_score  500  1000  0.3  20    normal  9.0
# 23                    MCP  accuracy_score  500  1000  0.3  20    normal  9.0
# 43                   SCAD  accuracy_score  500  1000  0.3  20    normal  9.0
# 63             VEBGLM-ash  accuracy_score  500  1000  0.3  20    normal  9.0
# 83   VEBGLM-point_laplace  accuracy_score  500  1000  0.3  20    normal  9.0
# 103   VEBGLM-point_normal  accuracy_score  500  1000  0.3  20    normal  9.0
# 123            elasticnet  accuracy_score  500  1000  0.3  20    normal  9.0
# 143                 lasso  accuracy_score  500  1000  0.3  20    normal  9.0
# 163                 ridge  accuracy_score  500  1000  0.3  20    normal  9.0
# 183              sparsevb  accuracy_score  500  1000  0.3  20    normal  9.0
# 203                varbvs  accuracy_score  500  1000  0.3  20    normal  9.0
#
#         score   run_time
# ...
